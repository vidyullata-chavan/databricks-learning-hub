# %%
# %sql
CREATE TABLE employee (id INT, name STRING, dept STRING) USING DELTA;

# %%
# %sql
INSERT INTO employee VALUES (1, 'Alice', 'Engineering'), (2, 'Bob', 'Sales')

# %%
# %sql
INSERT INTO employee VALUES (3, 'Atom', 'Engineering');
INSERT INTO employee VALUES (4, 'Bobby', 'Sales');

# %%
# %sql
select * from employee;

# %%
# %sql
INSERT INTO employee VALUES (5, 'Charlie', 'Marketing');

# %%
# %sql describe history employee

# %%
# %sql
SELECT * FROM employee VERSION AS OF 0;

# %%
# %sql
SELECT * FROM employee VERSION AS OF 1;

# %%
# %sql
SELECT * FROM employee VERSION AS OF 2;

# %%
# %sql
SELECT * FROM employee VERSION AS OF 4;

# %%
# %sql
SELECT * FROM employee TIMESTAMP AS OF '2026-03-26T09:16:32.000+00:00';

# %%
# %sql
DELETE FROM employee WHERE dept = 'Marketing';

# %%
# %sql
select * from default.employee

# %%
# %sql describe history employee

# %%
# %sql
RESTORE TABLE employee TO VERSION AS OF 4;

# %%
# %sql describe history employee

# %%
# %sql select * from default.employee

# %%
# %sql
CREATE OR REPLACE TABLE employee_shallow_clone_v2 SHALLOW CLONE employee VERSION AS OF 2;

# %%
# %sql describe history employee

# %%
# %sql describe history employee_shallow_clone_v2

# %%
# %sql select * from employee_shallow_clone_v2

# %%
# %sql
select * from triptable

# %%
# %sql
CREATE OR REPLACE MATERIALIZED VIEW mv1
AS SELECT
  TripID, StartStation, EndStation
FROM
  triptable
GROUP BY
  TripID;
