# %%
env = "dev"

# %%
import os
import sys
import platform
# print_info prints Python vesrion and Databricks runtime version
def print_env_info():
    print(f"env = {env}")
    print(f"Sys version = {sys.version}")
    print("Python version = " + platform.python_version())
    print("Databricks runtime version = " + 
          os.environ.get("DATABRICKS_RUNTIME_VERSION"))
# print_env_info()
