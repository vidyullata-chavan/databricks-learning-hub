# %% [markdown]
# # Introduction to Notebooks
# This notebook gives you introduction to **Databricks** notebooks.
# - Bullet 1
# - Bullet 2
# ## Heading 2
# Some _text_
# ### Heading 3
# `<h1>This is some code</h1>`

# %%
# New Notebook 2026-03-24 15_15_09
print("Hello Databricks!")
print("Bye!")

# %%
print("Hello again")
