# %%
# %sql
SELECT "test";

# %%
# %fs
ls /databricks-datasets/

# %%
# %sh
ps

# %%
# %pip list

# %%
# %run /Workspace/Users/r.vidyu.s@gmail.com/databricks-learning-hub/env_variables_functions

# %%
env

# %%
print_env_info()

# %%
# %fs ls /databricks-datasets/amazon

# %%
# %fs head dbfs:/databricks-datasets/amazon/README.md

# %%
# %fs ls dbfs:/databricks-datasets/tpch/data-001/customer/
